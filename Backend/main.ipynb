# %%
def start_up():
    # Understat Scraper
    # %run C:\Users\User\OneDrive\Documents\VSCode\score_prediction_tool\Backend\understat_scraping_tool.ipynb
    print('Understat Scraper has been run!')
    # Home vs Away tables/df
    # %run C:\Users\User\OneDrive\Documents\VSCode\score_prediction_tool\EDA_DF\EDA_Home_vs_Away.ipynb
    print('Home and Away file has been run!')
    # From tables/df
    # %run C:\Users\User\OneDrive\Documents\VSCode\score_prediction_tool\EDA_DF\EDA_Form.ipynb
    print('Form file has been run')
    # %run C:\Users\User\OneDrive\Documents\VSCode\score_prediction_tool\EDA_DF\EDA_Rank_Vs.ipynb
    print('Rank file has been run!')
start_up()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_21136\4083107710.py:4: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# 1
# 1
# 1
# 1
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\User\AppData\Local\Programs\Python\Python39\lib\genericpath.py:19, in exists(path)
#      18 try:
# ---> 19     os.stat(path)
#      20 except (OSError, ValueError):
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'C:\\Users\\User/.netrc'
#
# ...
