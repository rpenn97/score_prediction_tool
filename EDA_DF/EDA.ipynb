# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
# Overall DF

eng_df = pd.read_excel(r'EPL_understat.xlsx',sheet_name='gamesheet')
fra_df = pd.read_excel(r'Ligue1_understat.xlsx', sheet_name='gamesheet')
ger_df = pd.read_excel(r'Bundesliga_understat.xlsx', sheet_name='gamesheet')
ita_df = pd.read_excel(r'SerieA_understat.xlsx', sheet_name='gamesheet')
spa_df = pd.read_excel(r'LaLiga_understat.xlsx', sheet_name='gamesheet')

# Last 10 games Tables and DF

eng_l10_table_h = pd.read_excel(r'EPL_understat.xlsx',sheet_name='last10_home')
eng_l10_table_a = pd.read_excel(r'EPL_understat.xlsx',sheet_name='last10_away')
eng_l10_df = pd.read_excel(r'EPL_understat.xlsx',sheet_name='last10_gamesheet')

fra_l10_table_h = pd.read_excel(r'Ligue1_understat.xlsx',sheet_name='last10_home')
fra_l10_table_a = pd.read_excel(r'Ligue1_understat.xlsx',sheet_name='last10_away')
fra_l10_df = pd.read_excel(r'Ligue1_understat.xlsx',sheet_name='last10_gamesheet')

ger_l10_table_h = pd.read_excel(r'Bundesliga_understat.xlsx',sheet_name='last10_home')
ger_l10_table_a = pd.read_excel(r'Bundesliga_understat.xlsx',sheet_name='last10_away')
ger_l10_df = pd.read_excel(r'Bundesliga_understat.xlsx',sheet_name='last10_gamesheet')

ita_l10_table_h = pd.read_excel(r'SerieA_understat.xlsx',sheet_name='last10_home')
ita_l10_table_a = pd.read_excel(r'SerieA_understat.xlsx',sheet_name='last10_away')
ita_l10_df = pd.read_excel(r'SerieA_understat.xlsx',sheet_name='last10_gamesheet')

spa_l10_table_h = pd.read_excel(r'LaLiga_understat.xlsx',sheet_name='last10_home')
spa_l10_table_a = pd.read_excel(r'LaLiga_understat.xlsx',sheet_name='last10_away')
spa_l10_df = pd.read_excel(r'LaLiga_understat.xlsx',sheet_name='last10_gamesheet')

# Home v Away Tables

eng_table_h = pd.read_excel(r'EPL_understat.xlsx',sheet_name='home')
eng_table_a = pd.read_excel(r'EPL_understat.xlsx',sheet_name='away')

fra_table_h = pd.read_excel(r'Ligue1_understat.xlsx',sheet_name='home')
fra_table_a = pd.read_excel(r'Ligue1_understat.xlsx',sheet_name='away')

ger_table_h = pd.read_excel(r'Bundesliga_understat.xlsx',sheet_name='home')
ger_table_a = pd.read_excel(r'Bundesliga_understat.xlsx',sheet_name='away')

ita_table_h = pd.read_excel(r'SerieA_understat.xlsx',sheet_name='home')
ita_table_a = pd.read_excel(r'SerieA_understat.xlsx',sheet_name='away')

spa_table_h = pd.read_excel(r'LaLiga_understat.xlsx',sheet_name='home')
spa_table_a = pd.read_excel(r'LaLiga_understat.xlsx',sheet_name='away')

# Ranked Tables
eng_r1_table_h = pd.read_excel(r'EPL_understat.xlsx',sheet_name='rank1_home')
eng_r2_table_h = pd.read_excel(r'EPL_understat.xlsx',sheet_name='rank2_home')
eng_r3_table_h = pd.read_excel(r'EPL_understat.xlsx',sheet_name='rank3_home')
eng_r1_table_a = pd.read_excel(r'EPL_understat.xlsx',sheet_name='rank1_away')
eng_r2_table_a = pd.read_excel(r'EPL_understat.xlsx',sheet_name='rank2_away')
eng_r3_table_a = pd.read_excel(r'EPL_understat.xlsx',sheet_name='rank3_away')

fra_r1_table_h = pd.read_excel(r'Ligue1_understat.xlsx',sheet_name='rank1_home')
fra_r2_table_h = pd.read_excel(r'Ligue1_understat.xlsx',sheet_name='rank2_home')
fra_r3_table_h = pd.read_excel(r'Ligue1_understat.xlsx',sheet_name='rank3_home')
fra_r1_table_a = pd.read_excel(r'Ligue1_understat.xlsx',sheet_name='rank1_away')
fra_r2_table_a = pd.read_excel(r'Ligue1_understat.xlsx',sheet_name='rank2_away')
fra_r3_table_a = pd.read_excel(r'Ligue1_understat.xlsx',sheet_name='rank3_away')

ger_r1_table_h = pd.read_excel(r'Bundesliga_understat.xlsx',sheet_name='rank1_home')
ger_r2_table_h = pd.read_excel(r'Bundesliga_understat.xlsx',sheet_name='rank2_home')
ger_r3_table_h = pd.read_excel(r'Bundesliga_understat.xlsx',sheet_name='rank3_home')
ger_r1_table_a = pd.read_excel(r'Bundesliga_understat.xlsx',sheet_name='rank1_away')
ger_r2_table_a = pd.read_excel(r'Bundesliga_understat.xlsx',sheet_name='rank2_away')
ger_r3_table_a = pd.read_excel(r'Bundesliga_understat.xlsx',sheet_name='rank3_away')

ita_r1_table_h = pd.read_excel(r'SerieA_understat.xlsx',sheet_name='rank1_home')
ita_r2_table_h = pd.read_excel(r'SerieA_understat.xlsx',sheet_name='rank2_home')
ita_r3_table_h = pd.read_excel(r'SerieA_understat.xlsx',sheet_name='rank3_home')
ita_r1_table_a = pd.read_excel(r'SerieA_understat.xlsx',sheet_name='rank1_away')
ita_r2_table_a = pd.read_excel(r'SerieA_understat.xlsx',sheet_name='rank2_away')
ita_r3_table_a = pd.read_excel(r'SerieA_understat.xlsx',sheet_name='rank3_away')

spa_r1_table_h = pd.read_excel(r'LaLiga_understat.xlsx',sheet_name='rank1_home')
spa_r2_table_h = pd.read_excel(r'LaLiga_understat.xlsx',sheet_name='rank2_home')
spa_r3_table_h = pd.read_excel(r'LaLiga_understat.xlsx',sheet_name='rank3_home')
spa_r1_table_a = pd.read_excel(r'LaLiga_understat.xlsx',sheet_name='rank1_away')
spa_r2_table_a = pd.read_excel(r'LaLiga_understat.xlsx',sheet_name='rank2_away')
spa_r3_table_a = pd.read_excel(r'LaLiga_understat.xlsx',sheet_name='rank3_away')

list_df = [eng_df,fra_df,ger_df,ita_df,spa_df]
ov_df = pd.concat(list_df)
ov_df['win'] = ov_df.apply(lambda x: 1 if x['Pts'] == 3 else 0, axis=1) 
ov_df['draw'] = ov_df.apply(lambda x: 1 if x['Pts'] == 1 else 0, axis=1) 
ov_df['lose'] = ov_df.apply(lambda x: 1 if x['Pts'] == 0 else 0, axis=1) 
ov_df['home?'] = ov_df.apply(lambda x: 1 if x['H/A'] == "h" else 0, axis=1)
ov_df
# Out:
#      Unnamed: 0                date                      ID  \
# 0             0 2024-03-04 20:00:00   Sheffield United22163
# 1             1 2024-03-04 20:00:00            Arsenal22163
# 2             2 2024-03-03 15:30:00    Manchester City22160
# 3             3 2024-03-03 15:30:00  Manchester United22160
# 4             4 2024-03-03 13:00:00        Bournemouth22156
# ..          ...                 ...                     ...
# 755         755 2023-04-08 12:00:00              Elche19239
# 756         756 2023-04-07 19:00:00         Celta Vigo19238
# 757         757 2023-04-07 19:00:00            Sevilla19238
# 758         758 2023-04-02 12:00:00         Celta Vigo19231
# 759         759 2023-04-02 12:00:00            Almeria19231
#
#                   Team H/A     xG    xGC  G  GC   S  ...  first_goal  \
# 0     Sheffield United   h  0.201  2.485  0   6   5  ...           0
# 1              Arsenal   a  2.485  0.201  6   0  22  ...           1
# ...

# %%
def home_away_table(df):
    # new df
    df_h_a = df.groupby(["Team","H/A"]).agg({'played':'sum', 'xG':'sum', 'xGC':'sum','G':'sum', 'GC':'sum', 'Pts':'sum',
                                             'S':'sum', 'SC':'sum', 'QS': 'sum','QSC':'sum',
                                             'BTTS':'sum', 'Blank':'sum', 'CS':'sum','first_goal':'sum','first_conc':'sum'})
    h_a_sep = [x for _, x in df_h_a.groupby("H/A")]
    away_table = h_a_sep[0].droplevel("H/A")
    home_table = h_a_sep[1].droplevel("H/A")
    home_table = home_table.apply(pd.to_numeric)
    away_table = away_table.apply(pd.to_numeric)
    home_table['GD'] = home_table['G'] - home_table['GC']
    away_table['GD'] = away_table['G'] - away_table['GC']
    home_table['PPG'] = round(home_table['Pts'] / home_table['played'],2)
    away_table['PPG'] = round(away_table['Pts'] / away_table['played'],2)
    home_table['BTTS%'] = round(home_table['BTTS'] / home_table['played'],2)
    away_table['BTTS%'] = round(away_table['BTTS'] / away_table['played'],2)
    home_table['Blank%'] = round(home_table['Blank'] / home_table['played'],2)
    away_table['Blank%'] = round(away_table['Blank'] / away_table['played'],2)
    home_table['CS%'] = round(home_table['CS'] / home_table['played'],2)
    away_table['CS%'] = round(away_table['CS'] / away_table['played'],2)
    home_table['FG%'] = round(home_table['first_goal'] / home_table['played'],2)
    away_table['FG%'] = round(away_table['first_goal'] / away_table['played'],2)
    home_table['FC%'] = round(home_table['first_conc'] / home_table['played'],2)
    away_table['FC%'] = round(away_table['first_conc'] / away_table['played'],2)
    home_table['home?'] = 1
    away_table['home?'] = 0

    home_table = home_table[~(home_table['played'] <= 10)]
    away_table = away_table[~(away_table['played'] <= 10)]
    home_table = home_table[['played','xG','xGC','G','GC','GD','Pts','PPG','S','SC','QS','QSC','BTTS%','Blank%','CS%','FG%','FC%','home?']]
    away_table = away_table[['played','xG','xGC','G','GC','GD','Pts','PPG','S','SC','QS','QSC','BTTS%','Blank%','CS%','FG%','FC%','home?']]
    home_table = home_table.sort_values('PPG', ascending=False)
    away_table = away_table.sort_values('PPG', ascending=False)

    return home_table, away_table

eng_table_h, eng_table_a = home_away_table(eng_df)
fra_table_h, fra_table_a = home_away_table(fra_df)
ger_table_h, ger_table_a = home_away_table(ger_df)
ita_table_h, ita_table_a = home_away_table(ita_df)
spa_table_h, spa_table_a = home_away_table(spa_df)



ha_list = [eng_table_h, eng_table_a, fra_table_h, fra_table_a, ger_table_h, ger_table_a, ita_table_h, ita_table_a, spa_table_h, spa_table_a]
ov_ha_table = pd.concat(ha_list)
ov_ha_table
# Out:
#                    played      xG     xGC   G  GC  GD  Pts   PPG    S   SC  \
# Team
# Manchester City        20  42.516  16.256  51  16  35   52  2.60  339  134
# Liverpool              19  55.780  18.493  49  19  30   49  2.58  409  174
# Aston Villa            19  43.575  21.523  48  17  31   49  2.58  284  165
# Arsenal                19  46.623  17.175  53  21  32   45  2.37  332  145
# Manchester United      18  39.641  26.905  30  22   8   37  2.06  321  230
# ...                   ...     ...     ...  ..  ..  ..  ...   ...  ...  ...
# Mallorca               19  23.546  36.754  17  36 -19   12  0.63  189  296
# Celta Vigo             19  19.465  35.119  24  33  -9   12  0.63  190  263
# Cadiz                  20  19.218  43.370  11  30 -19   11  0.55  184  296
# Almeria                21  21.379  45.547  24  48 -24    7  0.33  203  360
# Granada                13  12.060  24.477  12  32 -20    2  0.15  119  169
#
# ...

# %%
def overall_table(df):
    # new df
    df_table = df.groupby("Team").agg({'played':'sum', 'xG':'sum', 'xGC':'sum','G':'sum', 'GC':'sum', 'Pts':'sum',
                                             'S':'sum', 'SC':'sum', 'QS': 'sum','QSC':'sum',
                                             'BTTS':'sum', 'Blank':'sum', 'CS':'sum','first_goal':'sum','first_conc':'sum'})
    df_table = df_table.apply(pd.to_numeric)
    df_table = df_table[~(df_table['played'] <= 20)]
    df_table['clinical'] = df_table['G']-df_table['xG']
    df_table['keeper'] = df_table['GC']-df_table['xGC']
    df_table['GD'] = df_table['G']-df_table['GC']
    df_table['xGD'] = df_table['xG']-df_table['xGC']
    df_table = df_table.iloc[:,1:].div(df_table.played, axis=0)

    return df_table

eng_ov_table = overall_table(eng_df)
fra_ov_table = overall_table(fra_df)
ger_ov_table = overall_table(ger_df)
ita_ov_table = overall_table(ita_df)
spa_ov_table = overall_table(spa_df)
eng_ov_table

league_list = [eng_ov_table, fra_ov_table, ger_ov_table, ita_ov_table, spa_ov_table]
ov_table = pd.concat(league_list)
ov_table
# Out:
#                      xG       xGC         G        GC       Pts          S  \
# Team
# Arsenal        2.122263  1.061053  2.473684  1.078947  2.078947  16.000000
# Aston Villa    1.945385  1.447769  1.974359  1.128205  2.025641  13.743590
# Bournemouth    1.500973  1.726838  1.270270  1.756757  1.243243  12.729730
# Brentford      1.714921  1.594500  1.447368  1.631579  1.157895  12.447368
# Brighton       2.021184  1.516289  1.894737  1.631579  1.473684  16.868421
# ...                 ...       ...       ...       ...       ...        ...
# Real Madrid    2.076395  1.159026  1.947368  0.868421  2.236842  15.868421
# Real Sociedad  1.530974  1.146342  1.394737  1.000000  1.657895  12.526316
# Sevilla        1.337289  1.512342  1.289474  1.368421  1.184211  13.026316
# Valencia       1.191216  1.293703  1.189189  1.189189  1.405405  10.513514
# Villarreal     1.785526  1.680079  1.789474  1.710526  1.368421  13.131579
#
# ...

# %%
# Goals Scored vs PPG
y = ov_table.Pts
x = ov_table.G.values.reshape(-1,1)
model = LinearRegression().fit(x,y)
r_sq = model.score(x,y)
intercept = model.intercept_
slope = model.coef_
y_pred = intercept + (slope*x)
fig, ax = plt.subplots(figsize=(10,10))
plt.scatter(x,y)
plt.ylim(0.4,2.55)
plt.plot(x,y_pred,c='red')
plt.yticks([0.5,1,1.5,2,2.5])
# plt.gca().invert_yaxis()
plt.xlabel('Goals Scored')
plt.ylabel('Points')
plt.title(f'LR on relationship between Goals Scored and Points Per Game ({r_sq}x)')
# Out:
# Text(0.5, 1.0, 'LR on relationship between Goals Scored and Points Per Game (0.7018975972607651x)')

# %%
# Goals Conceded vs PPG
y = ov_table.Pts
x = ov_table.GC.values.reshape(-1,1)
model = LinearRegression().fit(x,y)
r_sq = model.score(x,y)
intercept = model.intercept_
slope = model.coef_
y_pred = intercept + (slope*x)
fig, ax = plt.subplots(figsize=(10,10))
plt.scatter(x,y)
plt.ylim(0.45,2.5)
plt.plot(x,y_pred,c='red')
plt.yticks([0.5,1,1.5,2,2.5])
plt.gca().invert_yaxis()
plt.xlabel('Goals Conceded')
plt.ylabel('Points')
plt.title(f'LR on relationship between Goals Conceded and Points Per Game ({r_sq}x)')
# Out:
# Text(0.5, 1.0, 'LR on relationship between Goals Conceded and Points Per Game (0.6123503157677757x)')

# %%
# expected Goals Scored vs PPG
y = ov_table.Pts
x = ov_table.xG.values.reshape(-1,1)
model = LinearRegression().fit(x,y)
r_sq = model.score(x,y)
intercept = model.intercept_
slope = model.coef_
y_pred = intercept + (slope*x)
fig, ax = plt.subplots(figsize=(10,10))
plt.scatter(x,y)
plt.ylim(0.45,2.5)
plt.plot(x,y_pred,c='red')
plt.yticks([0.5,1,1.5,2,2.5])
# plt.gca().invert_yaxis()
plt.xlabel('Expected Goals')
plt.ylabel('Points')
plt.title(f'LR on relationship between Expected Goals and Points Per Game ({r_sq}x)')
# Out:
# Text(0.5, 1.0, 'LR on relationship between Expected Goals and Points Per Game (0.6532679436269124x)')

# %%
# expected Goals Conceded vs PPG
y = ov_table.Pts
x = ov_table.xGC.values.reshape(-1,1)
model = LinearRegression().fit(x,y)
r_sq = model.score(x,y)
intercept = model.intercept_
slope = model.coef_
y_pred = intercept + (slope*x)
fig, ax = plt.subplots(figsize=(10,10))
plt.scatter(x,y)
plt.ylim(0.45,2.5)
plt.plot(x,y_pred,c='red')
plt.yticks([0.5,1,1.5,2,2.5])
plt.gca().invert_yaxis()
plt.xlabel('Expected Goals Conceded')
plt.ylabel('Points')
plt.title(f'LR on relationship between Expected Goals Conceded and Points Per Game ({r_sq}x)')
# Out:
# Text(0.5, 1.0, 'LR on relationship between Expected Goals Conceded and Points Per Game (0.48162476015519073x)')

# %%
# Clinicality vs PPG
y = ov_table.Pts
x = ov_table.clinical.values.reshape(-1,1)
model = LinearRegression().fit(x,y)
r_sq = model.score(x,y)
intercept = model.intercept_
slope = model.coef_
y_pred = intercept + (slope*x)
fig, ax = plt.subplots(figsize=(10,10))
plt.scatter(x,y)
plt.ylim(0.45,2.5)
plt.plot(x,y_pred,c='red')
plt.yticks([0.5,1,1.5,2,2.5])
# plt.gca().invert_yaxis()
plt.xlabel('Clinicality (Goals - Expected Goals)')
plt.ylabel('Points per Game')
plt.title(f'LR on relationship between "Clinicality" and Points Per Game ({r_sq}x)')
# Out:
# Text(0.5, 1.0, 'LR on relationship between "Clinicality" and Points Per Game (0.061058302297467004x)')

# %%
# "Keeper Factor" vs PPG
y = ov_table.Pts
x = ov_table.keeper.values.reshape(-1,1)
model = LinearRegression().fit(x,y)
r_sq = model.score(x,y)
intercept = model.intercept_
slope = model.coef_
y_pred = intercept + (slope*x)
fig, ax = plt.subplots(figsize=(10,10))
plt.scatter(x,y)
plt.ylim(0.45,2.5)
plt.plot(x,y_pred,c='red')
plt.yticks([0.5,1,1.5,2,2.5])
plt.gca().invert_yaxis()
plt.xlabel('"Keeper Factor" (Goals Conceded - Expected Goals Conceded)')
plt.ylabel('Points per Game')
plt.title(f'LR on relationship between "Keeper Factor" and Points Per Game ({r_sq}x)')
# Out:
# Text(0.5, 1.0, 'LR on relationship between "Keeper Factor" and Points Per Game (0.10904703757518963x)')

# %%
# Quality Shots vs PPG
y = ov_table.Pts
x = ov_table.QS.values.reshape(-1,1)
model = LinearRegression().fit(x,y)
r_sq = model.score(x,y)
intercept = model.intercept_
slope = model.coef_
y_pred = intercept + (slope*x)
fig, ax = plt.subplots(figsize=(10,10))
plt.scatter(x,y)
plt.ylim(0.45,2.5)
plt.plot(x,y_pred,c='red')
plt.yticks([0.5,1,1.5,2,2.5])
# plt.gca().invert_yaxis()
plt.xlabel('Quality Shots')
plt.ylabel('Points Per Game')
plt.title(f'LR on relationship between "Quality Shots" and Points Per Game ({r_sq}x)')
# Out:
# Text(0.5, 1.0, 'LR on relationship between "Quality Shots" and Points Per Game (0.627211968470335x)')

# %%
# Quality Shots Conceded vs PPG
y = ov_table.Pts
x = ov_table.QSC.values.reshape(-1,1)
model = LinearRegression().fit(x,y)
r_sq = model.score(x,y)
intercept = model.intercept_
slope = model.coef_
y_pred = intercept + (slope*x)
fig, ax = plt.subplots(figsize=(10,10))
plt.scatter(x,y)
plt.ylim(0.45,2.5)
plt.plot(x,y_pred,c='red')
plt.yticks([0.5,1,1.5,2,2.5])
plt.gca().invert_yaxis()
plt.xlabel('Quality Shots Conceded')
plt.ylabel('Points Per Game')
plt.title(f'LR on relationship between "Quality Shots" Conceded and Points Per Game ({r_sq}x)')
# Out:
# Text(0.5, 1.0, 'LR on relationship between "Quality Shots" Conceded and Points Per Game (0.4267755164991993x)')

# %%
# Shots vs PPG
y = ov_table.Pts
x = ov_table.S.values.reshape(-1,1)
model = LinearRegression().fit(x,y)
r_sq = model.score(x,y)
intercept = model.intercept_
slope = model.coef_
y_pred = intercept + (slope*x)
fig, ax = plt.subplots(figsize=(10,10))
plt.scatter(x,y)
plt.ylim(0.45,2.5)
plt.plot(x,y_pred,c='red')
plt.yticks([0.5,1,1.5,2,2.5])
# plt.gca().invert_yaxis()
plt.xlabel('Shots')
plt.ylabel('Points per Game')
plt.title(f'LR on relationship between Shots and Points Per Game ({r_sq}x)')
# Out:
# Text(0.5, 1.0, 'LR on relationship between Shots and Points Per Game (0.5192148986863536x)')

# %%
# Shots Conceded vs PPG
y = ov_table.Pts
x = ov_table.SC.values.reshape(-1,1)
model = LinearRegression().fit(x,y)
r_sq = model.score(x,y)
intercept = model.intercept_
slope = model.coef_
y_pred = intercept + (slope*x)
fig, ax = plt.subplots(figsize=(10,10))
plt.scatter(x,y)
plt.ylim(0.45,2.5)
plt.plot(x,y_pred,c='red')
plt.yticks([0.5,1,1.5,2,2.5])
plt.gca().invert_yaxis()
plt.xlabel('Shots Conceded')
plt.ylabel('Points per Game')
plt.title(f'LR on relationship between Shots Conceded and Points Per Game ({r_sq}x)')
# Out:
# Text(0.5, 1.0, 'LR on relationship between Shots Conceded and Points Per Game (0.4002712224610133x)')

# %%
# BTTS vs PPG
y = ov_table.Pts
x = ov_table.BTTS.values.reshape(-1,1)
model = LinearRegression().fit(x,y)
r_sq = model.score(x,y)
intercept = model.intercept_
slope = model.coef_
y_pred = intercept + (slope*x)
fig, ax = plt.subplots(figsize=(10,10))
plt.scatter(x,y)
plt.ylim(0.45,2.5)
plt.plot(x,y_pred,c='red')
plt.yticks([0.5,1,1.5,2,2.5])
# plt.gca().invert_yaxis()
plt.xlabel('BTTS')
plt.ylabel('Points')
plt.title(f'LR on relationship between BTTS and Points Per Game ({r_sq}x)')
# Out:
# Text(0.5, 1.0, 'LR on relationship between BTTS and Points Per Game (0.003133625025383502x)')

# %%
# Clean Sheets vs PPG
y = ov_table.Pts
x = ov_table.CS.values.reshape(-1,1)
model = LinearRegression().fit(x,y)
r_sq = model.score(x,y)
intercept = model.intercept_
slope = model.coef_
y_pred = intercept + (slope*x)
fig, ax = plt.subplots(figsize=(10,10))
plt.scatter(x,y)
plt.ylim(0.45,2.5)
plt.plot(x,y_pred,c='red')
plt.yticks([0.5,1,1.5,2,2.5])
# plt.gca().invert_yaxis()
plt.xlabel('Clean Sheets')
plt.ylabel('Points')
plt.title(f'LR on relationship between Clean Sheets and Points Per Game ({r_sq}x)')
# Out:
# Text(0.5, 1.0, 'LR on relationship between Clean Sheets and Points Per Game (0.5574185245099916x)')

# %%
# Blanks vs PPG
y = ov_table.Pts
x = ov_table.Blank.values.reshape(-1,1)
model = LinearRegression().fit(x,y)
r_sq = model.score(x,y)
intercept = model.intercept_
slope = model.coef_
y_pred = intercept + (slope*x)
fig, ax = plt.subplots(figsize=(10,10))
plt.scatter(x,y)
plt.ylim(0.45,2.5)
plt.plot(x,y_pred,c='red')
plt.yticks([0.5,1,1.5,2,2.5])
plt.gca().invert_yaxis()
plt.xlabel('Blanks')
plt.ylabel('Points')
plt.title(f'LR on relationship between Blanks and Points Per Game ({r_sq}x)')
# Out:
# Text(0.5, 1.0, 'LR on relationship between Blanks and Points Per Game (0.5364891045162626x)')

# %%
# First Goal Scored vs PPG
y = ov_table.Pts
x = ov_table.first_goal.values.reshape(-1,1)
model = LinearRegression().fit(x,y)
r_sq = model.score(x,y)
intercept = model.intercept_
slope = model.coef_
y_pred = intercept + (slope*x)
fig, ax = plt.subplots(figsize=(10,10))
plt.scatter(x,y)
plt.ylim(0.45,2.5)
plt.plot(x,y_pred,c='red')
plt.yticks([0.5,1,1.5,2,2.5])
# plt.gca().invert_yaxis()
plt.xlabel('First Goalscorers')
plt.ylabel('Points')
plt.title(f'LR on relationship between First Goalscorers and Points Per Game ({r_sq}x)')
# Out:
# Text(0.5, 1.0, 'LR on relationship between First Goalscorers and Points Per Game (0.7429005381028128x)')

# %%
# First Goal Conceded vs PPG
y = ov_table.Pts
x = ov_table.first_conc.values.reshape(-1,1)
model = LinearRegression().fit(x,y)
r_sq = model.score(x,y)
intercept = model.intercept_
slope = model.coef_
y_pred = intercept + (slope*x)
fig, ax = plt.subplots(figsize=(10,10))
plt.scatter(x,y)
plt.ylim(0.45,2.5)
plt.plot(x,y_pred,c='red')
plt.yticks([0.5,1,1.5,2,2.5])
plt.gca().invert_yaxis()
plt.xlabel('First Goal Conceded')
plt.ylabel('Points')
plt.title(f'LR on relationship between First Goal Conceded and Points Per Game ({r_sq}x)')
# Out:
# Text(0.5, 1.0, 'LR on relationship between First Goal Conceded and Points Per Game (0.7229098122501122x)')

# %%
# Goal Difference vs PPG
y = ov_table.Pts
x = ov_table.GD.values.reshape(-1,1)
model = LinearRegression().fit(x,y)
r_sq = model.score(x,y)
intercept = model.intercept_
slope = model.coef_
y_pred = intercept + (slope*x)
fig, ax = plt.subplots(figsize=(10,10))
plt.scatter(x,y)
plt.ylim(0.45,2.5)
plt.plot(x,y_pred,c='red')
plt.yticks([0.5,1,1.5,2,2.5])
plt.gca().invert_yaxis()
plt.xlabel('Goal Difference')
plt.ylabel('Points')
plt.title(f'LR on relationship between Goal Difference and Points Per Game ({r_sq}x)')
# Out:
# Text(0.5, 1.0, 'LR on relationship between Goal Difference and Points Per Game (0.937403939116018x)')

# %%
# Expected Goal Difference vs PPG
y = ov_table.Pts
x = ov_table.xGD.values.reshape(-1,1)
model = LinearRegression().fit(x,y)
r_sq = model.score(x,y)
intercept = model.intercept_
slope = model.coef_
y_pred = intercept + (slope*x)
fig, ax = plt.subplots(figsize=(10,10))
plt.scatter(x,y)
plt.ylim(0.45,2.5)
plt.plot(x,y_pred,c='red')
plt.yticks([0.5,1,1.5,2,2.5])
plt.gca().invert_yaxis()
plt.xlabel('Expected Goal Difference')
plt.ylabel('Points')
plt.title(f'LR on relationship between Expected Goal Difference and Points Per Game ({r_sq}x)')
# Out:
# Text(0.5, 1.0, 'LR on relationship between Expected Goal Difference and Points Per Game (0.7767568329705581x)')

# %%
# Displaying Home v Away PPG

sns.boxplot(x="home?", y="PPG",hue="home?",data=ov_ha_table)
# Out:
# <Axes: xlabel='home?', ylabel='PPG'>

# %%
# Displaying Home v Away Goals Conceded

sns.boxplot(x="home?", y="GC",hue="home?",data=ov_ha_table)
# Out:
# <Axes: xlabel='home?', ylabel='GC'>

# %%
#Displaying differences in PPG against different 'Ranks' of opponent

rank_lists = [eng_r1_table_h,eng_r1_table_a,eng_r2_table_h,eng_r2_table_a,eng_r3_table_h,eng_r3_table_a,fra_r1_table_h,fra_r1_table_a,fra_r2_table_h,fra_r2_table_a,fra_r3_table_h,fra_r3_table_a,ger_r1_table_h,ger_r1_table_a,ger_r2_table_h,ger_r2_table_a,ger_r3_table_h,ger_r3_table_a,ita_r1_table_h,ita_r1_table_a,ita_r2_table_h,ita_r2_table_a,ita_r3_table_h,ita_r3_table_a,spa_r1_table_h,spa_r1_table_a,spa_r2_table_h,spa_r2_table_a,spa_r3_table_h,spa_r3_table_a]
ov_rank_table = pd.concat(rank_lists)

sns.boxplot(x="Rank", y="PPG",hue="home?",data=ov_rank_table)
# Out:
# <Axes: xlabel='Rank', ylabel='PPG'>

# %%
ov_df_ml = ov_df.drop(['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0','date','ID','Team','H/A','Opp','played','date_int','match_ID'], axis = 1)

# %%
# Machine Learning Approach (Logistic Regression) to predict winning teams
y_win = ov_df_ml.win
x_win = ov_df_ml.drop(['win','draw','lose','G','GC','Pts'], axis = 1)
xtrain_win, xtest_win, ytrain_win, ytest_win = train_test_split(x_win,y_win, train_size = 0.8, random_state = 42)
model_win = LogisticRegression()
model_win.fit(xtrain_win,ytrain_win)
y_preds_win = model_win.predict(xtest_win)
accuracy_win = accuracy_score(ytest_win, y_preds_win)
accuracy_win
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.853625170998632

# %%
# Machine Learning Approach (Logistic Regression) to predict drawing teams
y_draw = ov_df_ml.draw
x_draw = ov_df_ml.drop(['win','draw','lose','G','GC','Pts'], axis = 1)
xtrain_draw, xtest_draw, ytrain_draw, ytest_draw = train_test_split(x_draw,y_draw, train_size = 0.8, random_state = 42)
model_draw = LogisticRegression()
model_draw.fit(xtrain_draw,ytrain_draw)
y_preds_draw = model_draw.predict(xtest_draw)
accuracy_draw = accuracy_score(ytest_draw, y_preds_draw)
accuracy_draw
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.8303693570451436

# %%
# Machine Learning Approach (Logistic Regression) to predict losing teams
y_lose = ov_df_ml.lose
x_lose = ov_df_ml.drop(['win','draw','lose','G','GC','Pts'], axis = 1)
xtrain_lose, xtest_lose, ytrain_lose, ytest_lose = train_test_split(x_lose,y_lose, train_size = 0.8, random_state = 42)
model_lose = LogisticRegression()
model_lose.fit(xtrain_lose,ytrain_lose)
y_preds_lose = model_lose.predict(xtest_lose)
accuracy_lose = accuracy_score(ytest_lose, y_preds_lose)
accuracy_lose
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.8700410396716827

# %%
my_params = np.array([[2,1.05,20,10,2,1,1,0,0,1,0,3,1]])
model_win.predict(my_params)
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
model_draw.predict(my_params)
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
model_lose.predict(my_params)
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
def combine_and_net(home_df,away_df):
    df = pd.DataFrame({'Home PPG' : home_df['PPG'], 'Away PPG': away_df['PPG']})
    for team in df:
        df['net'] = df['Home PPG'] - df['Away PPG']
    df2 = df.drop(['Home PPG', 'Away PPG'], axis=1)
    df2.loc['AVERAGE'] = df2.mean()
    df = df.drop('net', axis=1)
    df.loc['AVERAGE'] = df.mean()

    return df, df2

# %%
eng_ha, eng_net = combine_and_net(eng_table_h, eng_table_a)
fra_ha, fra_net = combine_and_net(fra_table_h, fra_table_a)
ger_ha, ger_net = combine_and_net(ger_table_h, ger_table_a)
ita_ha, ita_net = combine_and_net(ita_table_h, ita_table_a)
spa_ha, spa_net = combine_and_net(spa_table_h, spa_table_a)

# %%
eng_ha.sort_values("Home PPG").plot(kind="barh")
plt.title("Away PPG")
plt.ylabel("Team")
plt.xlabel("Points Per Game")
# Out:
# Text(0.5, 0, 'Points Per Game')

# %%
eng_net.sort_values("net").plot(kind="barh")
plt.title("PPG Home minus Away")
plt.ylabel("Team")
plt.xlabel("Points Per Game net")
# Out:
# Text(0.5, 0, 'Points Per Game net')

# %%
fra_ha.sort_values("Home PPG").plot(kind="barh")
plt.title("Away PPG")
plt.ylabel("Team")
plt.xlabel("Points Per Game")
# Out:
# Text(0.5, 0, 'Points Per Game')

# %%
fra_net.sort_values("net").plot(kind="barh")
plt.title("PPG Home minus Away")
plt.ylabel("Team")
plt.xlabel("Points Per Game net")
# Out:
# Text(0.5, 0, 'Points Per Game net')

# %%
ger_ha.sort_values("Home PPG").plot(kind="barh")
plt.title("Away PPG")
plt.ylabel("Team")
plt.xlabel("Points Per Game")
# Out:
# Text(0.5, 0, 'Points Per Game')

# %%
ger_net.sort_values("net").plot(kind="barh")
plt.title("PPG Home minus Away")
plt.ylabel("Team")
plt.xlabel("Points Per Game net")
# Out:
# Text(0.5, 0, 'Points Per Game net')

# %%
ita_ha.sort_values("Home PPG").plot(kind="barh")
plt.title("Away PPG")
plt.ylabel("Team")
plt.xlabel("Points Per Game")
# Out:
# Text(0.5, 0, 'Points Per Game')

# %%
ita_net.sort_values("net").plot(kind="barh")
plt.title("PPG Home minus Away")
plt.ylabel("Team")
plt.xlabel("Points Per Game net")
# Out:
# Text(0.5, 0, 'Points Per Game net')

# %%
spa_ha.sort_values("Home PPG").plot(kind="barh")
plt.title("Away PPG")
plt.ylabel("Team")
plt.xlabel("Points Per Game")
# Out:
# Text(0.5, 0, 'Points Per Game')

# %%
spa_net.sort_values("net").plot(kind="barh")
plt.title("PPG Home minus Away")
plt.ylabel("Team")
plt.xlabel("Points Per Game net")
# Out:
# Text(0.5, 0, 'Points Per Game net')

# %%
lines = eng_l10_df.plot.line(x='Pts', y='date')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[184], line 1
# ----> 1 lines = eng_l10_df.plot.line(x='Pts', y='date',c='Team')
#
# File c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\plotting\_core.py:1100, in PlotAccessor.line(self, x, y, **kwargs)
#    1034 @Appender(
#    1035     """
#    1036     See Also
#    (...)
#    1092     self, x: Hashable | None = None, y: Hashable | None = None, **kwargs
#    1093 ) -> PlotAccessor:
#    1094     """
#    1095     Plot Series or DataFrame as lines.
#    1096
#    1097     This function is useful to plot lines using DataFrame's values
#    1098     as coordinates.
#    1099     """
# -> 1100     return self(kind="line", x=x, y=y, **kwargs)
#
# ...
