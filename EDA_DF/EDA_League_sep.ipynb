# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import statsmodels.formula.api as smf
import statsmodels.api as sm

# %%
# Overall DF

eng_df = pd.read_excel(r'EPL_understat.xlsx',sheet_name='gamesheet')
fra_df = pd.read_excel(r'Ligue1_understat.xlsx', sheet_name='gamesheet')
ger_df = pd.read_excel(r'Bundesliga_understat.xlsx', sheet_name='gamesheet')
ita_df = pd.read_excel(r'SerieA_understat.xlsx', sheet_name='gamesheet')
spa_df = pd.read_excel(r'LaLiga_understat.xlsx', sheet_name='gamesheet')

# Last 10 games Tables

eng_l10_table_h = pd.read_excel(r'EPL_understat.xlsx',sheet_name='last10_home')
eng_l10_table_a = pd.read_excel(r'EPL_understat.xlsx',sheet_name='last10_away')

fra_l10_table_h = pd.read_excel(r'Ligue1_understat.xlsx',sheet_name='last10_home')
fra_l10_table_a = pd.read_excel(r'Ligue1_understat.xlsx',sheet_name='last10_away')

ger_l10_table_h = pd.read_excel(r'Bundesliga_understat.xlsx',sheet_name='last10_home')
ger_l10_table_a = pd.read_excel(r'Bundesliga_understat.xlsx',sheet_name='last10_away')

ita_l10_table_h = pd.read_excel(r'SerieA_understat.xlsx',sheet_name='last10_home')
ita_l10_table_a = pd.read_excel(r'SerieA_understat.xlsx',sheet_name='last10_away')

spa_l10_table_h = pd.read_excel(r'LaLiga_understat.xlsx',sheet_name='last10_home')
spa_l10_table_a = pd.read_excel(r'LaLiga_understat.xlsx',sheet_name='last10_away')

# Home v Away Tables

eng_table_h = pd.read_excel(r'EPL_understat.xlsx',sheet_name='home')
eng_table_a = pd.read_excel(r'EPL_understat.xlsx',sheet_name='away')

fra_table_h = pd.read_excel(r'Ligue1_understat.xlsx',sheet_name='home')
fra_table_a = pd.read_excel(r'Ligue1_understat.xlsx',sheet_name='away')

ger_table_h = pd.read_excel(r'Bundesliga_understat.xlsx',sheet_name='home')
ger_table_a = pd.read_excel(r'Bundesliga_understat.xlsx',sheet_name='away')

ita_table_h = pd.read_excel(r'SerieA_understat.xlsx',sheet_name='home')
ita_table_a = pd.read_excel(r'SerieA_understat.xlsx',sheet_name='away')

spa_table_h = pd.read_excel(r'LaLiga_understat.xlsx',sheet_name='home')
spa_table_a = pd.read_excel(r'LaLiga_understat.xlsx',sheet_name='away')

# Ranked Tables
eng_r1_table_h = pd.read_excel(r'EPL_understat.xlsx',sheet_name='rank1_home')
eng_r2_table_h = pd.read_excel(r'EPL_understat.xlsx',sheet_name='rank2_home')
eng_r3_table_h = pd.read_excel(r'EPL_understat.xlsx',sheet_name='rank3_home')
eng_r1_table_a = pd.read_excel(r'EPL_understat.xlsx',sheet_name='rank1_away')
eng_r2_table_a = pd.read_excel(r'EPL_understat.xlsx',sheet_name='rank2_away')
eng_r3_table_a = pd.read_excel(r'EPL_understat.xlsx',sheet_name='rank3_away')

fra_r1_table_h = pd.read_excel(r'Ligue1_understat.xlsx',sheet_name='rank1_home')
fra_r2_table_h = pd.read_excel(r'Ligue1_understat.xlsx',sheet_name='rank2_home')
fra_r3_table_h = pd.read_excel(r'Ligue1_understat.xlsx',sheet_name='rank3_home')
fra_r1_table_a = pd.read_excel(r'Ligue1_understat.xlsx',sheet_name='rank1_away')
fra_r2_table_a = pd.read_excel(r'Ligue1_understat.xlsx',sheet_name='rank2_away')
fra_r3_table_a = pd.read_excel(r'Ligue1_understat.xlsx',sheet_name='rank3_away')

ger_r1_table_h = pd.read_excel(r'Bundesliga_understat.xlsx',sheet_name='rank1_home')
ger_r2_table_h = pd.read_excel(r'Bundesliga_understat.xlsx',sheet_name='rank2_home')
ger_r3_table_h = pd.read_excel(r'Bundesliga_understat.xlsx',sheet_name='rank3_home')
ger_r1_table_a = pd.read_excel(r'Bundesliga_understat.xlsx',sheet_name='rank1_away')
ger_r2_table_a = pd.read_excel(r'Bundesliga_understat.xlsx',sheet_name='rank2_away')
ger_r3_table_a = pd.read_excel(r'Bundesliga_understat.xlsx',sheet_name='rank3_away')

ita_r1_table_h = pd.read_excel(r'SerieA_understat.xlsx',sheet_name='rank1_home')
ita_r2_table_h = pd.read_excel(r'SerieA_understat.xlsx',sheet_name='rank2_home')
ita_r3_table_h = pd.read_excel(r'SerieA_understat.xlsx',sheet_name='rank3_home')
ita_r1_table_a = pd.read_excel(r'SerieA_understat.xlsx',sheet_name='rank1_away')
ita_r2_table_a = pd.read_excel(r'SerieA_understat.xlsx',sheet_name='rank2_away')
ita_r3_table_a = pd.read_excel(r'SerieA_understat.xlsx',sheet_name='rank3_away')

spa_r1_table_h = pd.read_excel(r'LaLiga_understat.xlsx',sheet_name='rank1_home')
spa_r2_table_h = pd.read_excel(r'LaLiga_understat.xlsx',sheet_name='rank2_home')
spa_r3_table_h = pd.read_excel(r'LaLiga_understat.xlsx',sheet_name='rank3_home')
spa_r1_table_a = pd.read_excel(r'LaLiga_understat.xlsx',sheet_name='rank1_away')
spa_r2_table_a = pd.read_excel(r'LaLiga_understat.xlsx',sheet_name='rank2_away')
spa_r3_table_a = pd.read_excel(r'LaLiga_understat.xlsx',sheet_name='rank3_away')

# %%
spa_r3_table_a
# Out:
#                Team  Rank  played      xG     xGC   G  GC  GD  Pts   PPG    S  \
# 0          Espanyol     3       1   1.346   1.831   2   1   1    3  3.00   10
# 1       Real Madrid     3       5  11.930   5.884  10   2   8   13  2.60   95
# 2        Las Palmas     3       3   3.126   2.602   5   2   3    7  2.33   36
# 3   Atletico Madrid     3       8  18.488  10.270  23   9  14   17  2.12  109
# 4           Sevilla     3       6   8.814  11.286  12   5   7   12  2.00   81
# 5     Real Sociedad     3       4   5.807   2.627   6   3   3    8  2.00   47
# 6            Girona     3       7  12.308   9.683   9   5   4   14  2.00   95
# 7          Valencia     3       7   8.178  10.419  13   8   5   13  1.86   68
# 8     Athletic Club     3       5   7.140   3.600   5   3   2    9  1.80   66
# 9           Osasuna     3       4   4.085   4.425   5   3   2    7  1.75   39
# 10   Rayo Vallecano     3       4   5.725   5.702   4   4   0    7  1.75   50
# 11         Mallorca     3       7   9.787   9.107   9  11  -2    9  1.29   75
# 12       Real Betis     3       4   4.818   7.571   4   3   1    5  1.25   46
# 13       Celta Vigo     3       4   3.391   8.026   5   5   0    5  1.25   34
# 14        Barcelona     3       7  13.707   8.559  12  13  -1    8  1.14  102
# 15           Alaves     3       4   5.243   5.792   4   4   0    4  1.00   52
# 16       Villarreal     3       4   4.058   7.001   6   8  -2    4  1.00   33
# 17          Almeria     3       5   4.578   7.829   7   8  -1    4  0.80   40
# 18            Cadiz     3       5   5.667  10.372   3   5  -2    4  0.80   57
# 19           Getafe     3       4   4.037   7.867   3   4  -1    3  0.75   24
# 20          Granada     3       2   4.304   3.593   3   4  -1    1  0.50   26
# 21  Real Valladolid     3       3   1.142   5.261   1   4  -3    1  0.33   21
# 22            Elche     3       2   2.504   3.260   1   3  -2    0  0.00   26
#
#      SC  QS  QSC  BTTS%  Blank%   CS%   FG%   FC%  home?
# 0    15   2    2   1.00    0.00  0.00  1.00  0.00      0
# 1    66  16    7   0.40    0.00  0.60  0.80  0.20      0
# 2    29   5    4   0.67    0.00  0.33  0.67  0.33      0
# 3   130  32    8   0.50    0.12  0.38  0.88  0.12      0
# 4   107  13   16   0.67    0.00  0.33  0.67  0.33      0
# 5    39   7    3   0.50    0.25  0.50  0.50  0.25      0
# 6   102  17   11   0.43    0.29  0.43  0.43  0.43      0
# 7    70  13   13   0.71    0.00  0.29  0.71  0.29      0
# 8    47   9    3   0.60    0.40  0.40  0.60  0.00      0
# 9    55   5    3   0.50    0.00  0.50  0.50  0.50      0
# 10   59   6    7   0.00    0.50  0.75  0.50  0.25      0
# 11   86  13   12   0.43    0.29  0.43  0.29  0.57      0
# 12   72   6    8   0.50    0.25  0.50  0.75  0.00      0
# 13   66   4   11   0.50    0.50  0.25  0.50  0.25      0
# 14   75  17   11   1.00    0.00  0.00  0.29  0.71      0
# 15   59   6    6   0.25    0.50  0.25  0.25  0.75      0
# 16   61   6   10   1.00    0.00  0.00  0.75  0.25      0
# 17   78   5    6   0.80    0.20  0.00  0.60  0.40      0
# 18   76   6   14   0.60    0.40  0.20  0.40  0.40      0
# 19   70   4   10   0.50    0.50  0.25  0.50  0.25      0
# 20   28   5    5   0.50    0.50  0.00  0.00  1.00      0
# 21   50   0    6   0.33    0.67  0.33  0.00  0.67      0
# 22   24   4    5   0.50    0.50  0.00  0.00  1.00      0

# %%
def home_away_table(df):
    # new df
    df_h_a = df.groupby(["Team","H/A"]).agg({'played':'sum', 'xG':'sum', 'xGC':'sum','G':'sum', 'GC':'sum', 'Pts':'sum',
                                             'S':'sum', 'SC':'sum', 'QS': 'sum','QSC':'sum',
                                             'BTTS':'sum', 'Blank':'sum', 'CS':'sum','first_goal':'sum','first_conc':'sum'})
    h_a_sep = [x for _, x in df_h_a.groupby("H/A")]
    away_table = h_a_sep[0].droplevel("H/A")
    home_table = h_a_sep[1].droplevel("H/A")
    home_table = home_table.apply(pd.to_numeric)
    away_table = away_table.apply(pd.to_numeric)
    home_table['GD'] = home_table['G'] - home_table['GC']
    away_table['GD'] = away_table['G'] - away_table['GC']
    home_table['PPG'] = round(home_table['Pts'] / home_table['played'],2)
    away_table['PPG'] = round(away_table['Pts'] / away_table['played'],2)
    home_table['BTTS%'] = round(home_table['BTTS'] / home_table['played'],2)
    away_table['BTTS%'] = round(away_table['BTTS'] / away_table['played'],2)
    home_table['Blank%'] = round(home_table['Blank'] / home_table['played'],2)
    away_table['Blank%'] = round(away_table['Blank'] / away_table['played'],2)
    home_table['CS%'] = round(home_table['CS'] / home_table['played'],2)
    away_table['CS%'] = round(away_table['CS'] / away_table['played'],2)
    home_table['FG%'] = round(home_table['first_goal'] / home_table['played'],2)
    away_table['FG%'] = round(away_table['first_goal'] / away_table['played'],2)
    home_table['FC%'] = round(home_table['first_conc'] / home_table['played'],2)
    away_table['FC%'] = round(away_table['first_conc'] / away_table['played'],2)
    home_table['home?'] = 1
    away_table['home?'] = 0

    home_table = home_table[~(home_table['played'] <= 10)]
    away_table = away_table[~(away_table['played'] <= 10)]
    home_table = home_table[['played','xG','xGC','G','GC','GD','Pts','PPG','S','SC','QS','QSC','BTTS%','Blank%','CS%','FG%','FC%','home?']]
    away_table = away_table[['played','xG','xGC','G','GC','GD','Pts','PPG','S','SC','QS','QSC','BTTS%','Blank%','CS%','FG%','FC%','home?']]
    home_table = home_table.sort_values('PPG', ascending=False)
    away_table = away_table.sort_values('PPG', ascending=False)

    return home_table, away_table

eng_table_h, eng_table_a = home_away_table(eng_df)
fra_table_h, fra_table_a = home_away_table(fra_df)
ger_table_h, ger_table_a = home_away_table(ger_df)
ita_table_h, ita_table_a = home_away_table(ita_df)
spa_table_h, spa_table_a = home_away_table(spa_df)

# %%
def overall_table(df):
    # new df
    df_table = df.groupby("Team").agg({'played':'sum', 'xG':'sum', 'xGC':'sum','G':'sum', 'GC':'sum', 'Pts':'sum',
                                             'S':'sum', 'SC':'sum', 'QS': 'sum','QSC':'sum',
                                             'BTTS':'sum', 'Blank':'sum', 'CS':'sum','first_goal':'sum','first_conc':'sum'})
    df_table = df_table.apply(pd.to_numeric)
    df_table = df_table[~(df_table['played'] <= 20)]
    df_table['clinical'] = df_table['G']-df_table['xG']
    df_table['keeper'] = df_table['GC']-df_table['xGC']
    df_table['GD'] = df_table['G']-df_table['GC']
    df_table['xGD'] = df_table['xG']-df_table['xGC']
    df_table = df_table.iloc[:,1:].div(df_table.played, axis=0)

    return df_table

eng1_ov_table = overall_table(eng_df)
fra1_ov_table = overall_table(fra_df)
ger1_ov_table = overall_table(ger_df)
ita1_ov_table = overall_table(ita_df)
spa1_ov_table = overall_table(spa_df)
eng1_ov_table
# Out:
#                                xG       xGC         G        GC       Pts  \
# Team
# Arsenal                  2.122263  1.061053  2.473684  1.078947  2.078947
# Aston Villa              1.945385  1.447769  1.974359  1.128205  2.025641
# Bournemouth              1.500973  1.726838  1.270270  1.756757  1.243243
# Brentford                1.714921  1.594500  1.447368  1.631579  1.157895
# Brighton                 2.021184  1.516289  1.894737  1.631579  1.473684
# Burnley                  1.003630  1.942852  0.925926  2.222222  0.481481
# Chelsea                  1.823757  1.748216  1.486486  1.729730  1.135135
# Crystal Palace           1.275947  1.457658  1.342105  1.631579  1.210526
# Everton                  1.772263  1.685053  1.131579  1.473684  1.105263
# Fulham                   1.291184  1.874000  1.473684  1.526316  1.263158
# Liverpool                2.379921  1.251263  2.421053  1.131579  2.289474
# Luton                    1.472846  2.521192  1.423077  2.076923  0.769231
# Manchester City          2.225605  0.959289  2.342105  0.921053  2.368421
# Manchester United        1.847553  1.728789  1.394737  1.236842  1.736842
# Newcastle United         2.235500  1.592158  2.078947  1.526316  1.605263
# Nottingham Forest        1.230538  1.678564  1.307692  1.820513  0.923077
# Sheffield United         0.993296  2.310556  0.814815  2.666667  0.481481
# Tottenham                1.805447  1.759158  2.078947  1.736842  1.710526
# West Ham                 1.495718  1.933487  1.564103  1.641026  1.512821
# Wolverhampton Wanderers  1.299711  1.923395  1.342105  1.684211  1.368421
#
#                                  S         SC        QS       QSC      BTTS  \
# Team
# Arsenal                  16.000000   9.078947  2.631579  1.421053  0.526316
# Aston Villa              13.743590  10.743590  2.461538  2.102564  0.615385
# Bournemouth              12.729730  14.945946  1.783784  1.972973  0.513514
# Brentford                12.447368  14.631579  2.315789  2.078947  0.631579
# Brighton                 16.868421  11.526316  2.605263  1.736842  0.763158
# Burnley                  10.481481  15.148148  1.222222  2.222222  0.518519
# Chelsea                  13.783784  13.783784  2.459459  2.189189  0.648649
# Crystal Palace           12.315789  11.578947  1.368421  2.026316  0.605263
# Everton                  13.868421  14.394737  2.368421  1.947368  0.473684
# Fulham                   12.052632  13.868421  1.578947  2.552632  0.500000
# Liverpool                18.368421  10.763158  3.236842  1.921053  0.684211
# Luton                    12.269231  17.038462  1.692308  3.461538  0.769231
# Manchester City          17.184211   8.000000  2.842105  1.210526  0.631579
# Manchester United        15.684211  15.421053  2.289474  1.947368  0.447368
# Newcastle United         14.552632  12.973684  3.026316  1.736842  0.578947
# Nottingham Forest        10.307692  13.974359  1.538462  2.025641  0.666667
# Sheffield United          9.074074  17.444444  1.185185  2.851852  0.518519
# Tottenham                14.921053  13.473684  2.342105  2.421053  0.842105
# West Ham                 11.820513  16.512821  1.897436  2.512821  0.589744
# Wolverhampton Wanderers  11.526316  14.684211  1.526316  2.447368  0.578947
#
#                             Blank        CS  first_goal  first_conc  clinical  \
# Team
# Arsenal                  0.131579  0.342105    0.736842    0.263158  0.351421
# Aston Villa              0.128205  0.282051    0.615385    0.358974  0.028974
# Bournemouth              0.297297  0.216216    0.432432    0.540541 -0.230703
# Brentford                0.184211  0.184211    0.578947    0.421053 -0.267553
# Brighton                 0.131579  0.157895    0.421053    0.526316 -0.126447
# Burnley                  0.407407  0.074074    0.370370    0.629630 -0.077704
# Chelsea                  0.243243  0.135135    0.378378    0.594595 -0.337270
# Crystal Palace           0.236842  0.236842    0.368421    0.552632  0.066158
# Everton                  0.342105  0.263158    0.421053    0.500000 -0.640684
# Fulham                   0.342105  0.210526    0.447368    0.500000  0.182500
# Liverpool                0.026316  0.315789    0.605263    0.368421  0.041132
# Luton                    0.153846  0.076923    0.307692    0.692308 -0.049769
# Manchester City          0.078947  0.289474    0.684211    0.315789  0.116500
# Manchester United        0.263158  0.315789    0.552632    0.421053 -0.452816
# Newcastle United         0.184211  0.263158    0.526316    0.447368 -0.156553
# Nottingham Forest        0.230769  0.128205    0.461538    0.512821  0.077154
# Sheffield United         0.444444  0.037037    0.222222    0.777778 -0.178481
# Tottenham                0.000000  0.157895    0.684211    0.394737  0.273500
# West Ham                 0.205128  0.230769    0.512821    0.461538  0.068385
# Wolverhampton Wanderers  0.210526  0.236842    0.447368    0.526316  0.042395
#
#                            keeper        GD       xGD
# Team
# Arsenal                  0.017895  1.394737  1.061211
# Aston Villa             -0.319564  0.846154  0.497615
# Bournemouth              0.029919 -0.486486 -0.225865
# Brentford                0.037079 -0.184211  0.120421
# Brighton                 0.115289  0.263158  0.504895
# Burnley                  0.279370 -1.296296 -0.939222
# Chelsea                 -0.018486 -0.243243  0.075541
# Crystal Palace           0.173921 -0.289474 -0.181711
# Everton                 -0.211368 -0.342105  0.087211
# Fulham                  -0.347684 -0.052632 -0.582816
# Liverpool               -0.119684  1.289474  1.128658
# Luton                   -0.444269 -0.653846 -1.048346
# Manchester City         -0.038237  1.421053  1.266316
# Manchester United       -0.491947  0.157895  0.118763
# Newcastle United        -0.065842  0.552632  0.643342
# Nottingham Forest        0.141949 -0.512821 -0.448026
# Sheffield United         0.356111 -1.851852 -1.317259
# Tottenham               -0.022316  0.342105  0.046289
# West Ham                -0.292462 -0.076923 -0.437769
# Wolverhampton Wanderers -0.239184 -0.342105 -0.623684

# %%
def LR_plot_PPG(df_table):
    y = df_table.Pts
    x = df_table.xGD.values.reshape(-1,1)
    model = LinearRegression().fit(x,y)
    r_sq = model.score(x,y)
    intercept = model.intercept_
    slope = model.coef_
    y_pred = intercept + (slope*x)
    fig, ax = plt.subplots(figsize=(10,10))
    plt.scatter(x,y)
    plt.ylim(0.45,2.5)
    plt.plot(x,y_pred,c='red')
    plt.yticks([0.5,1,1.5,2,2.5])
    # plt.gca().invert_yaxis()
    plt.ylabel('Points per Game')
    plt.title(f'LR on relationship between Goals Scored and Points Per Game ({r_sq}x)')
    for i, txt in enumerate(df_table.index):
        plt.annotate(txt, (x[i], y[i]))

eng_G_LR = LR_plot_PPG(eng1_ov_table)
# fra_G_LR = LR_plot_PPG(fra1_ov_table)
# ger_G_LR = LR_plot_PPG(ger1_ov_table)
# ita_G_LR = LR_plot_PPG(ita1_ov_table)
# spa_G_LR = LR_plot_PPG(spa1_ov_table)

eng_G_LR
fra_G_LR
ger_G_LR
ita_G_LR
spa_G_LR
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_17256\3062630507.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(txt, (x[i], y[i]))

# %%
Y = eng_ov_table['PPG']
X = eng_ov_table[['G','GC','xG','xGC','S','SC','QS','QSC','BTTS_d','CS_d','Blank_d','FG_d','FC_d']]
X = sm.add_constant(X)

# Kitchen Sink model
ks = sm.OLS(Y, X)
ks_res = ks.fit()
# ks_res.summary()
ksf =  smf.ols(' PPG ~ G + GC + xG + xGC + S + SC + QS + QSC + BTTS_d + CS_d + Blank_d + FG_d + FC_d', data=eng_ov_table)
ksf_res = ksf.fit()
# ksf_res.summary()
# sns.pairplot(X);
# round(eng_ov_table.corr(),2)
# Out:
#                Placement  played    xG   xGC   xGD     G    GC    GD   Pts  \
# Placement           1.00   -0.63 -0.83  0.41 -0.79 -0.90  0.70 -0.92 -0.98
# played             -0.63    1.00  0.70  0.01  0.52  0.66 -0.19  0.55  0.72
# xG                 -0.83    0.70  1.00 -0.43  0.93  0.90 -0.62  0.88  0.89
# xGC                 0.41    0.01 -0.43  1.00 -0.73 -0.50  0.70 -0.62 -0.44
# xGD                -0.79    0.52  0.93 -0.73  1.00  0.88 -0.75  0.92  0.85
# G                  -0.90    0.66  0.90 -0.50  0.88  1.00 -0.62  0.96  0.93
# GC                  0.70   -0.19 -0.62  0.70 -0.75 -0.62  1.00 -0.82 -0.71
# GD                 -0.92    0.55  0.88 -0.62  0.92  0.96 -0.82  1.00  0.94
# Pts                -0.98    0.72  0.89 -0.44  0.85  0.93 -0.71  0.94  1.00
# PPG                -0.98    0.66  0.88 -0.48  0.86  0.93 -0.75  0.96  1.00
# S                  -0.85    0.74  0.95 -0.43  0.89  0.87 -0.61  0.86  0.90
# SC                  0.29    0.23 -0.24  0.90 -0.55 -0.40  0.61 -0.51 -0.29
# QS                 -0.78    0.67  0.99 -0.41  0.91  0.87 -0.58  0.85  0.84
# QSC                 0.24    0.04 -0.36  0.87 -0.63 -0.30  0.51 -0.40 -0.26
# BTTS_d             -0.10    0.00  0.18 -0.02  0.14  0.33  0.11  0.20  0.12
# Blank_d             0.71   -0.44 -0.71  0.33 -0.67 -0.83  0.45 -0.77 -0.73
# CS_d               -0.82    0.72  0.76 -0.34  0.71  0.71 -0.70  0.77  0.86
# FG_d               -0.84    0.62  0.77 -0.45  0.76  0.86 -0.63  0.86  0.87
# FC_d                0.86   -0.74 -0.82  0.45 -0.80 -0.87  0.67 -0.88 -0.91
# clinicality        -0.36    0.06  0.00 -0.26  0.11  0.45 -0.15  0.38  0.31
# keeper factor       0.38   -0.26 -0.25 -0.37 -0.04 -0.17  0.41 -0.27 -0.35
#
#                 PPG  ...    SC    QS   QSC  BTTS_d  Blank_d  CS_d  FG_d  FC_d  \
# Placement     -0.98  ...  0.29 -0.78  0.24   -0.10     0.71 -0.82 -0.84  0.86
# played         0.66  ...  0.23  0.67  0.04    0.00    -0.44  0.72  0.62 -0.74
# xG             0.88  ... -0.24  0.99 -0.36    0.18    -0.71  0.76  0.77 -0.82
# xGC           -0.48  ...  0.90 -0.41  0.87   -0.02     0.33 -0.34 -0.45  0.45
# xGD            0.86  ... -0.55  0.91 -0.63    0.14    -0.67  0.71  0.76 -0.80
# G              0.93  ... -0.40  0.87 -0.30    0.33    -0.83  0.71  0.86 -0.87
# GC            -0.75  ...  0.61 -0.58  0.51    0.11     0.45 -0.70 -0.63  0.67
# GD             0.96  ... -0.51  0.85 -0.40    0.20    -0.77  0.77  0.86 -0.88
# Pts            1.00  ... -0.29  0.84 -0.26    0.12    -0.73  0.86  0.87 -0.91
# PPG            1.00  ... -0.34  0.83 -0.29    0.14    -0.75  0.85  0.86 -0.89
# S              0.89  ... -0.24  0.92 -0.34    0.18    -0.70  0.79  0.74 -0.81
# SC            -0.34  ...  1.00 -0.21  0.69   -0.20     0.31 -0.11 -0.25  0.22
# QS             0.83  ... -0.21  1.00 -0.35    0.19    -0.69  0.70  0.74 -0.78
# QSC           -0.29  ...  0.69 -0.35  1.00    0.19     0.06 -0.25 -0.27  0.29
# BTTS_d         0.14  ... -0.20  0.19  0.19    1.00    -0.72 -0.29  0.15 -0.04
# Blank_d       -0.75  ...  0.31 -0.69  0.06   -0.72     1.00 -0.43 -0.72  0.67
# CS_d           0.85  ... -0.11  0.70 -0.25   -0.29    -0.43  1.00  0.71 -0.83
# FG_d           0.86  ... -0.25  0.74 -0.27    0.15    -0.72  0.71  1.00 -0.97
# FC_d          -0.89  ...  0.22 -0.78  0.29   -0.04     0.67 -0.83 -0.97  1.00
# clinicality    0.32  ... -0.41 -0.05  0.06    0.38    -0.44  0.06  0.40 -0.31
# keeper factor -0.36  ... -0.34 -0.23 -0.44    0.17     0.17 -0.47 -0.25  0.30
#
#                clinicality  keeper factor
# Placement            -0.36           0.38
# played                0.06          -0.26
# xG                    0.00          -0.25
# xGC                  -0.26          -0.37
# xGD                   0.11          -0.04
# G                     0.45          -0.17
# GC                   -0.15           0.41
# GD                    0.38          -0.27
# Pts                   0.31          -0.35
# PPG                   0.32          -0.36
# S                     0.05          -0.25
# SC                   -0.41          -0.34
# QS                   -0.05          -0.23
# QSC                   0.06          -0.44
# BTTS_d                0.38           0.17
# Blank_d              -0.44           0.17
# CS_d                  0.06          -0.47
# FG_d                  0.40          -0.25
# FC_d                 -0.31           0.30
# clinicality           1.00           0.14
# keeper factor         0.14           1.00
#
# [21 rows x 21 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 29
#      26 plt.ylabel('Points')
#      27 plt.title(f'LR on relationship between Goals Conceded and Points Per Game ({r_sq}x)')
# ---> 29 plt.subplot(1,1,2)
#      30 model = LinearRegression().fit(x2,y2)
#      31 r_sq = model.score(x2,y2)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\pyplot.py:1440, in subplot(*args, **kwargs)
#    1437 fig = gcf()
#    1439 # First, search for an existing subplot with a matching spec.
# -> 1440 key = SubplotSpec._from_subplot_args(fig, args)
#    1442 for ax in fig.axes:
#    1443     # If we found an Axes at the position, we can re-use it if the user passed no
#    1444     # kwargs or if the axes class and kwargs are identical.
#    1445     if (ax.get_subplotspec() == key
#    1446         and (kwargs == {}
#    1447              or (ax._projection_init
#    1448                  == fig._process_projection_requirements(**kwargs)))):
#
# File c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\gridspec.py:599, in SubplotSpec._from_subplot_args(figure, args)
#     597 else:
#     598     if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# --> 599         raise ValueError(
#     600             f"num must be an integer with 1 <= num <= {rows*cols}, "
#     601             f"not {num!r}"
#     602         )
#     603     i = j = num
#     604 return gs[i-1:j]
#
# ValueError: num must be an integer with 1 <= num <= 1, not 2

# %%
# Goals Scored vs PPG
y = eng_ov_table.PPG
x = eng_ov_table.GC.values.reshape(-1,1)
model = LinearRegression().fit(x,y)
r_sq = model.score(x,y)
intercept = model.intercept_
slope = model.coef_
y_pred = intercept + (slope*x)
fig, ax = plt.subplots(figsize=(10,10))
plt.scatter(x,y)
plt.ylim(0.4,2.55)
plt.plot(x,y_pred,c='red')
plt.yticks([0.5,1,1.5,2,2.5])
plt.gca().invert_yaxis()
plt.xlabel('Goals Conceded')
plt.ylabel('Points')
plt.title(f'LR on relationship between Goals Conceded and Points Per Game ({r_sq}x)')
# Out:
# Text(0.5, 1.0, 'LR on relationship between Goals Conceded and Points Per Game (0.5642936159783071x)')

# %%
# expected Goals Scored vs PPG
y = eng_ov_table.PPG
x = eng_ov_table.xG.values.reshape(-1,1)
model = LinearRegression().fit(x,y)
r_sq = model.score(x,y)
intercept = model.intercept_
slope = model.coef_
y_pred = intercept + (slope*x)
fig, ax = plt.subplots(figsize=(10,10))
plt.scatter(x,y)
plt.ylim(0.45,2.5)
plt.plot(x,y_pred,c='red')
plt.yticks([0.5,1,1.5,2,2.5])
# plt.gca().invert_yaxis()
plt.xlabel('Expected Goals')
plt.ylabel('Points')
plt.title(f'LR on relationship between Expected Goals and Points Per Game ({r_sq}x)')
# Out:
# Text(0.5, 1.0, 'LR on relationship between Expected Goals and Points Per Game (0.7771374796033101x)')

# %%
# expected Goals Conceded vs PPG
y = eng_ov_table.PPG
x = eng_ov_table.xGC.values.reshape(-1,1)
model = LinearRegression().fit(x,y)
r_sq = model.score(x,y)
intercept = model.intercept_
slope = model.coef_
y_pred = intercept + (slope*x)
fig, ax = plt.subplots(figsize=(10,10))
plt.scatter(x,y)
plt.ylim(0.45,2.5)
plt.plot(x,y_pred,c='red')
plt.yticks([0.5,1,1.5,2,2.5])
plt.gca().invert_yaxis()
plt.xlabel('Expected Goals Conceded')
plt.ylabel('Points')
plt.title(f'LR on relationship between Expected Goals Conceded and Points Per Game ({r_sq}x)')
# Out:
# Text(0.5, 1.0, 'LR on relationship between Expected Goals Conceded and Points Per Game (0.23178959140035182x)')

# %%
# Clinicality vs PPG
y = eng_ov_table.PPG
x = eng_ov_table.clinicality.values.reshape(-1,1)
model = LinearRegression().fit(x,y)
r_sq = model.score(x,y)
intercept = model.intercept_
slope = model.coef_
y_pred = intercept + (slope*x)
fig, ax = plt.subplots(figsize=(10,10))
plt.scatter(x,y)
plt.ylim(0.45,2.5)
plt.plot(x,y_pred,c='red')
plt.yticks([0.5,1,1.5,2,2.5])
# plt.gca().invert_yaxis()
plt.xlabel('Clinicality (Goals - Expected Goals)')
plt.ylabel('Points per Game')
plt.title(f'LR on relationship between "Clinicality" and Points Per Game ({r_sq}x)')
# Out:
# Text(0.5, 1.0, 'LR on relationship between "Clinicality" and Points Per Game (0.10168407132557877x)')

# %%
def LR_generator_G(df_table):
    y = df_table.PPG
    x = df_table.G.values.reshape(-1,1)
    model = LinearRegression().fit(x,y)
    r_sq = model.score(x,y)
    intercept = model.intercept_
    slope = model.coef_
    y_pred = intercept + (slope*x)
    fig, ax = plt.subplots(figsize=(10,10))
    plt.scatter(x,y)
    plt.ylim(0.45,2.5)
    plt.plot(x,y_pred,c='red')
    plt.yticks([0.5,1,1.5,2,2.5])
    # plt.gca().invert_yaxis()
    plt.xlabel('Goals Scored')
    plt.ylabel('Points per Game')
    plt.title(f'LR on relationship between Goals Scored and Points Per Game ({r_sq}x)')

eng_G_LR = LR_generator_G(eng_ov_table)
eng_G_LR
